# %% [markdown]
# # Online classification scene by scene

# %%
import pandas as pd
import numpy as np
from numpy import unique
from numpy import random
import seaborn as sns
from sklearn.preprocessing import StandardScaler 
import matplotlib.pyplot as plt 
# %matplotlib inline

import time
import zmq
import array
from utils import myfct,mydisplay
import pickle

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import DBSCAN
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# %% [markdown]
# ### A la recherche de bon 'Tuning' de SVM

# %%
# %%time

#saving_file = "forgetting_algorithm"
#saving_file = "CieLAB_Experiment"
#saving_file = "Random_Forest"
saving_file = "env3_table3"
saving_for_experience = False
starting_batch = 13



model = SVC(kernel = 'rbf',probability=True,class_weight = 'balanced')
#model = RandomForestClassifier()

#model = GaussianProcessRegressor(kernel = None)
nbBatch = 8
nbScene = 15
nbIterPerScene = 5
nb_model_for_removing_worst_SVP = 1000
proportion_of_completion = 0.8#before eliminating the bad SVP
threshold_of_object = 0.42# taux d'objet dans la BDD au dela duquel on ne prends plus les SVP d'objets

batch_y_train_acc_exp = []
batch_y_train_acc_true = []
batch_X_train_acc_rough = []

#noForget_batch_y_train_acc_exp = []
#noForget_batch_y_train_acc_true = []
#noForget_batch_X_train_acc_rough = []

selected_FPFH_number = 0

context = zmq.Context()
socket = context.socket(zmq.REP)
socket.bind("tcp://*:5562")
#Sending NbBatch, NbScene & NbIterPerScene
message = socket.recv()
send_string = str(nbBatch)
socket.send_string(send_string)
message = socket.recv()
send_string = str(nbScene)
socket.send_string(send_string)
message = socket.recv()
send_string = str(nbIterPerScene)
socket.send_string(send_string)
print("data sent to C++")
y1,y2,y3,y4,y5 = [],[],[],[],[]

for l in range (nbBatch):
    X_train_acc_rough = []
    y_train_acc_true = []
    y_train_acc_exp = []
    noForget_X_train_acc_rough = []
    noForget_y_train_acc_true = []
    noForget_y_train_acc_exp = []
    print("batch Numero ",l+1)
    for i in range(nbScene):
        for j in range(nbIterPerScene+1):
            
            if(j!=0):
                old_y_train_true = np.copy(y_train_true)
                old_X_train_rough = np.copy(X_train_rough)
                old_selected_FPFH_number = selected_FPFH_number

            message = socket.recv()
            message1 = array.array('B',message)
            nb_svp_moved,FPFHL_preshape = message1[0],message1[1:]
            

            if(nb_svp_moved!=0 and nb_svp_moved!=255):
                label = 1
                svp_moved_rough, FPFHL_preshape = message1[1:nb_svp_moved*2+1],message1[nb_svp_moved*2+1:]
                svp_moved = []
                for k in range(nb_svp_moved):
                    #On recupère les Numéro des svp ayant bougés; il sont codés à l'aide de 2 char
                    num_svp = int(svp_moved_rough[2*k]*255 + svp_moved_rough[2*k+1])
                    if(num_svp<=int(len(FPFHL_preshape)/49)):
                        #if(num_svp<=len(old_X_train_rough)):
                        svp_moved.append(int(svp_moved_rough[2*k]*255 + svp_moved_rough[2*k+1]))
                    print("svp_moved[k] :",svp_moved[k])
                    print("int(old_y_train_true[svp_moved[k]]) :",int(old_y_train_true[int(svp_moved[k])-1]))
            else:
                label = message1[0]

            FPFH_LAB_L = np.reshape(FPFHL_preshape,(int(len(FPFHL_preshape)/49),49)).astype(int)
            X_train_rough = np.zeros((len(FPFH_LAB_L),48))
            y_train_true = np.zeros(len(FPFH_LAB_L))
            for k in range(len(FPFH_LAB_L)):
                X_train_rough[k][:48] = FPFH_LAB_L[k][:48]
                y_train_true[k] = FPFH_LAB_L[k][-1]
                 
            #On veux au moins trois FPFH d'objet pour partir sur un modele relativement stable           
            if(sum(y_train_acc_exp) < 3 or (len(y_train_acc_exp) - sum(y_train_acc_exp)) < 3 or len(y_train_acc_exp) < 3):
                if(j!=0):
                    if(nb_svp_moved == 0):
                        y_train_acc_exp.append(0)
                        y_train_acc_true.append(int(old_y_train_true[old_selected_FPFH_number-1]))
                        X_train_acc_rough.append(old_X_train_rough[old_selected_FPFH_number-1])
                        #y_train_acc_true.append(int(old_y_train_true[old_selected_FPFH_number]))
                        #X_train_acc_rough.append(old_X_train_rough[old_selected_FPFH_number])
                        
                        #noForget_y_train_acc_exp.append(0)
                        #noForget_y_train_acc_true.append(int(old_y_train_true[old_selected_FPFH_number-1]))
                        #noForget_X_train_acc_rough.append(old_X_train_rough[old_selected_FPFH_number-1])
                        
                    else:
                        for k in range(int(nb_svp_moved)):
                            num_sv = int(svp_moved[k])-1
                            #num_sv = int(svp_moved[k])
                            y_train_acc_exp.append(1)
                            y_train_acc_true.append(int(old_y_train_true[num_sv]))
                            X_train_acc_rough.append(old_X_train_rough[num_sv])
                            
                            #noForget_y_train_acc_exp.append(1)
                            #noForget_y_train_acc_true.append(int(old_y_train_true[num_sv]))
                            #noForget_X_train_acc_rough.append(old_X_train_rough[num_sv])
       
                selected_FPFH_number = int(random.uniform(0,len(X_train_rough)))
            
            else:
                if(j!=0):
                    if(nb_svp_moved == 0):
                        y_train_acc_exp.append(0)
                        y_train_acc_true.append(int(old_y_train_true[old_selected_FPFH_number-1]))
                        X_train_acc_rough.append(old_X_train_rough[old_selected_FPFH_number-1])
                        #y_train_acc_true.append(int(old_y_train_true[old_selected_FPFH_number]))
                        #X_train_acc_rough.append(old_X_train_rough[old_selected_FPFH_number])
                        
                        #noForget_y_train_acc_exp.append(0)
                        #noForget_y_train_acc_true.append(int(old_y_train_true[old_selected_FPFH_number-1]))
                        #noForget_X_train_acc_rough.append(old_X_train_rough[old_selected_FPFH_number-1])
                        
                    else:
                        if(sum(y_train_acc_exp)/len(y_train_acc_exp)<threshold_of_object):
                            for k in range(int(nb_svp_moved)):
                                num_sv = int(svp_moved[k])-1
                            #num_sv = int(svp_moved[k])
                                y_train_acc_exp.append(1)
                                y_train_acc_true.append(int(old_y_train_true[num_sv]))
                                X_train_acc_rough.append(old_X_train_rough[num_sv])
                                
                                
                                #noForget_y_train_acc_exp.append(1)
                                #noForget_y_train_acc_true.append(int(old_y_train_true[num_sv]))
                                #noForget_X_train_acc_rough.append(old_X_train_rough[num_sv])
                                
                                y3.append(int(old_y_train_true[num_sv-1]))
                                y2.append(int(old_y_train_true[num_sv]))
            
                #On réentraine le model avec toutes les données accumulées jusqu'a présent
                X_train_acc = myfct.normalize(X_train_acc_rough)
                model.fit(X_train_acc,y_train_acc_exp)  
                X_train = myfct.normalize(X_train_rough)
                preds_proba = model.predict_proba(X_train)
                selected_FPFH_number = myfct.getRelevantFPFH(preds_proba,y_train_acc_exp,threshold_of_object)

            #Si on arrive à ce niveau du batch (ici 80%) on lance l'algo doublie des SVP non cohérents
            if(i*j==int(proportion_of_completion*nbScene*nbIterPerScene) and len(y_train_acc_exp)>20):
                X_train_acc_rough,y_train_acc_exp,y_train_acc_true = myfct.forget_worst_sample(
                    model,nb_model_for_removing_worst_SVP,X_train_acc_rough,y_train_acc_exp,y_train_acc_true)
            
            socket.send_string(str(selected_FPFH_number))
            if(label!=255):        
                print(" y_train_true",old_y_train_true[old_selected_FPFH_number])
                
    #on relance l'algo doublie des SVP non cohérents  
    if(len(y_train_acc_exp)>20):
        X_train_acc_rough,y_train_acc_exp,y_train_acc_true = myfct.forget_worst_sample(
                    model,nb_model_for_removing_worst_SVP,X_train_acc_rough,y_train_acc_exp,y_train_acc_true) 
    
    batch_y_train_acc_exp.append(y_train_acc_exp)
    batch_y_train_acc_true.append(y_train_acc_true)
    batch_X_train_acc_rough.append(X_train_acc_rough)
    
    without_X_train_acc_rough = []
    #for r in range(len(X_train_acc_rough)):
    #    without_X_train_acc_rough.append(X_train_acc_rough[r][:33])
    #X_train_acc_rough = without_X_train_acc_rough
    #batch_X_train_acc_rough.append(X_train_acc_rough)
    
    
    
    if(saving_for_experience):
        #path_without_y_train_acc_exp = "../Plan_exp/" + saving_file + "/batch_num_"+str(l+starting_batch)+"without_y_train_acc_exp"
        #myfct.writePickler(path_without_y_train_acc_exp,y_train_acc_exp)
        #path_without_y_train_acc_true = "../Plan_exp/" + saving_file + "/batch_num_"+str(l+starting_batch)+"without_y_train_acc_true"
        #myfct.writePickler(path_without_y_train_acc_true,y_train_acc_true)
        #path_without_X_train_acc_rough = "../Plan_exp/" + saving_file + "/batch_num_"+str(l+starting_batch)+"without_X_train_acc_rough"
        #myfct.writePickler(path_without_X_train_acc_rough,without_X_train_acc_rough)

        path_y_train_acc_exp = "../Plan_exp/" + saving_file + "/batch_num_"+str(l+starting_batch)+"y_train_acc_exp"
        myfct.writePickler(path_y_train_acc_exp,y_train_acc_exp)
        path_y_train_acc_true = "../Plan_exp/" + saving_file + "/batch_num_"+str(l+starting_batch)+"y_train_acc_true"
        myfct.writePickler(path_y_train_acc_true,y_train_acc_true)
        path_X_train_acc_rough = "../Plan_exp/" + saving_file + "/batch_num_"+str(l+starting_batch)+"X_train_acc_rough"
        myfct.writePickler(path_X_train_acc_rough,X_train_acc_rough)
# Out:
# data sent to C++
# batch Numero  1
#  y_train_true 0.0
# svp_moved[k] : 331
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 328
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 325
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 324
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 257
# int(old_y_train_true[svp_moved[k]]) : 0
#  y_train_true 0.0
# svp_moved[k] : 70
# int(old_y_train_true[svp_moved[k]]) : 1
#  y_train_true 0.0
#  y_train_true 0.0
# svp_moved[k] : 669
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 668
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 389
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 345
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 344
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 342
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 341
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 339
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 38
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 262
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 266
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 267
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 329
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 330
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 334
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 338
# int(old_y_train_true[svp_moved[k]]) : 0
#  y_train_true 0.0
#  y_train_true 0.0
# threshold_y_true :  0.84 Mean :  0.43   certainty_FPFH :  0.58
#  y_train_true 0.0
# threshold_y_true :  0.81 Mean :  0.47   certainty_FPFH :  0.9
#  y_train_true 0.0
# threshold_y_true :  0.78 Mean :  0.39   certainty_FPFH :  0.41
#  y_train_true 0.0
# threshold_y_true :  0.75 Mean :  0.3   certainty_FPFH :  0.34
#  y_train_true 0.0
# threshold_y_true :  0.75 Mean :  0.24   certainty_FPFH :  0.37
# threshold_y_true :  0.73 Mean :  0.3   certainty_FPFH :  0.26
#  y_train_true 0.0
# threshold_y_true :  0.7 Mean :  0.2   certainty_FPFH :  0.25
#  y_train_true 0.0
# svp_moved[k] : 679
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 342
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 338
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.7 Mean :  0.25   certainty_FPFH :  0.21
#  y_train_true 0.0
# svp_moved[k] : 724
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 715
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 343
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 342
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 338
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 337
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 395
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 336
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 335
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 276
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 274
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 390
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 448
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 679
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 334
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 275
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 332
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 339
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 357
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 344
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 583
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.7 Mean :  0.28   certainty_FPFH :  0.23
#  y_train_true 0.0
# threshold_y_true :  0.68 Mean :  0.15   certainty_FPFH :  0.24
#  y_train_true 0.0
# threshold_y_true :  0.68 Mean :  0.15   certainty_FPFH :  0.29
# threshold_y_true :  0.66 Mean :  0.14   certainty_FPFH :  0.75
#  y_train_true 0.0
# threshold_y_true :  0.64 Mean :  0.33   certainty_FPFH :  0.38
#  y_train_true 0.0
# threshold_y_true :  0.62 Mean :  0.17   certainty_FPFH :  0.14
#  y_train_true 0.0
# threshold_y_true :  0.61 Mean :  0.12   certainty_FPFH :  0.26
#  y_train_true 0.0
# threshold_y_true :  0.59 Mean :  0.33   certainty_FPFH :  0.78
#  y_train_true 0.0
# threshold_y_true :  0.59 Mean :  0.19   certainty_FPFH :  0.81
# svp_moved[k] : 182
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 105
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 170
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 112
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 164
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 165
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 169
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 171
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 173
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 175
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.59 Mean :  0.25   certainty_FPFH :  0.81
#  y_train_true 1.0
# threshold_y_true :  0.57 Mean :  0.34   certainty_FPFH :  0.8
#  y_train_true 0.0
# threshold_y_true :  0.56 Mean :  0.17   certainty_FPFH :  0.19
#  y_train_true 0.0
# threshold_y_true :  0.55 Mean :  0.18   certainty_FPFH :  0.08
#  y_train_true 0.0
# threshold_y_true :  0.53 Mean :  0.26   certainty_FPFH :  0.34
#  y_train_true 0.0
# threshold_y_true :  0.53 Mean :  0.18   certainty_FPFH :  0.63
# svp_moved[k] : 169
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 168
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 167
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 131
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.53 Mean :  0.05   certainty_FPFH :  0.26
#  y_train_true 0.0
# threshold_y_true :  0.52 Mean :  0.32   certainty_FPFH :  0.25
#  y_train_true 0.0
# threshold_y_true :  0.51 Mean :  0.17   certainty_FPFH :  0.79
#  y_train_true 0.0
# svp_moved[k] : 356
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 168
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 167
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 104
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.51 Mean :  0.14   certainty_FPFH :  0.84
#  y_train_true 0.0
# svp_moved[k] : 356
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 168
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 167
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 642
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.51 Mean :  0.34   certainty_FPFH :  0.82
#  y_train_true 0.0
# threshold_y_true :  0.51 Mean :  0.23   certainty_FPFH :  0.38
# threshold_y_true :  0.5 Mean :  0.1   certainty_FPFH :  0.68
#  y_train_true 0.0
# svp_moved[k] : 174
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 173
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 172
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 378
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 171
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 163
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 118
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.5 Mean :  0.31   certainty_FPFH :  0.89
#  y_train_true 0.0
# svp_moved[k] : 570
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 336
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 118
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.5 Mean :  0.3   certainty_FPFH :  0.5
#  y_train_true 0.0
# svp_moved[k] : 387
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 170
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 165
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 108
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 122
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 117
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 123
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 162
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 124
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 164
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.5 Mean :  0.09   certainty_FPFH :  0.07
#  y_train_true 1.0
# svp_moved[k] : 623
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 163
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 160
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 336
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 123
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 292
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 122
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 109
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 340
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 170
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 171
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 172
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 162
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 159
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 335
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.5 Mean :  0.32   certainty_FPFH :  0.07
#  y_train_true 0.0
# threshold_y_true :  0.5 Mean :  0.11   certainty_FPFH :  0.25
# threshold_y_true :  0.48 Mean :  0.33   certainty_FPFH :  0.13
#  y_train_true 0.0
# threshold_y_true :  0.47 Mean :  0.34   certainty_FPFH :  0.75
#  y_train_true 0.0
# threshold_y_true :  0.46 Mean :  0.06   certainty_FPFH :  0.04
#  y_train_true 0.0
# threshold_y_true :  0.45 Mean :  0.19   certainty_FPFH :  0.03
#  y_train_true 0.0
# threshold_y_true :  0.44 Mean :  0.21   certainty_FPFH :  0.37
#  y_train_true 0.0
# threshold_y_true :  0.44 Mean :  0.28   certainty_FPFH :  0.04
# threshold_y_true :  0.44 Mean :  0.05   certainty_FPFH :  0.04
#  y_train_true 0.0
# svp_moved[k] : 346
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.44 Mean :  0.18   certainty_FPFH :  0.47
#  y_train_true 0.0
# threshold_y_true :  0.43 Mean :  0.3   certainty_FPFH :  0.37
#  y_train_true 0.0
# threshold_y_true :  0.42 Mean :  0.25   certainty_FPFH :  0.06
#  y_train_true 0.0
# svp_moved[k] : 581
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 348
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.42 Mean :  0.05   certainty_FPFH :  0.02
#  y_train_true 0.0
# threshold_y_true :  0.42 Mean :  0.22   certainty_FPFH :  0.02
# threshold_y_true :  0.41 Mean :  0.58   certainty_FPFH :  0.7
#  y_train_true 0.0
# threshold_y_true :  0.4 Mean :  0.59   certainty_FPFH :  0.57
#  y_train_true 0.0
# threshold_y_true :  0.4 Mean :  0.59   certainty_FPFH :  0.76
#  y_train_true 0.0
# svp_moved[k] : 579
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 564
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 582
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 178
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 177
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 174
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 583
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 180
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 124
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 183
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 167
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 171
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.5 Mean :  0.05   certainty_FPFH :  0.5
#  y_train_true 0.0
# svp_moved[k] : 582
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 564
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 179
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 177
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 170
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 583
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 180
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 178
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 126
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.5 Mean :  0.18   certainty_FPFH :  0.07
#  y_train_true 0.0
# threshold_y_true :  0.5 Mean :  0.07   certainty_FPFH :  0.04
# threshold_y_true :  0.5 Mean :  0.25   certainty_FPFH :  0.66
#  y_train_true 0.0
# threshold_y_true :  0.49 Mean :  0.19   certainty_FPFH :  0.73
#  y_train_true 0.0
# svp_moved[k] : 494
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 493
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 331
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 343
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.49 Mean :  0.06   certainty_FPFH :  0.13
#  y_train_true 0.0
# svp_moved[k] : 345
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 331
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 330
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 298
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.49 Mean :  0.2   certainty_FPFH :  0.04
#  y_train_true 0.0
# threshold_y_true :  0.48 Mean :  0.15   certainty_FPFH :  0.38
#  y_train_true 0.0
# threshold_y_true :  0.48 Mean :  0.17   certainty_FPFH :  0.04
# threshold_y_true :  0.47 Mean :  0.33   certainty_FPFH :  0.05
#  y_train_true 0.0
# threshold_y_true :  0.47 Mean :  0.15   certainty_FPFH :  0.02
#  y_train_true 0.0
# threshold_y_true :  0.46 Mean :  0.34   certainty_FPFH :  0.49
#  y_train_true 0.0
# threshold_y_true :  0.45 Mean :  0.22   certainty_FPFH :  0.02
#  y_train_true 0.0
# threshold_y_true :  0.45 Mean :  0.32   certainty_FPFH :  0.8
#  y_train_true 0.0
# threshold_y_true :  0.45 Mean :  0.08   certainty_FPFH :  0.03
# svp_moved[k] : 261
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 129
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.45 Mean :  0.22   certainty_FPFH :  0.03
#  y_train_true 0.0
# svp_moved[k] : 333
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 111
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 110
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 109
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 130
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 91
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 261
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 80
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 131
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 79
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.45 Mean :  0.29   certainty_FPFH :  0.79
#  y_train_true 0.0
# threshold_y_true :  0.44 Mean :  0.33   certainty_FPFH :  0.6
#  y_train_true 0.0
# threshold_y_true :  0.44 Mean :  0.33   certainty_FPFH :  0.82
#  y_train_true 0.0
# threshold_y_true :  0.43 Mean :  0.29   certainty_FPFH :  0.23
# prediction removed : 0.0
# is diferent : 1
# prediction removed : 0.0
# is diferent : 1
# prediction removed : 0.010752688172043012
# is diferent : 1
# prediction removed : 0.9130434782608695
# is diferent : 1
# prediction removed : 0.6708860759493671
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 0.0
# is diferent : 1
# prediction removed : 0.2127659574468085
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
#  y_train_true 0.0
# threshold_y_true :  0.43 Mean :  0.29   certainty_FPFH :  0.26
# threshold_y_true :  0.43 Mean :  0.29   certainty_FPFH :  0.0
#  y_train_true 0.0
# threshold_y_true :  0.42 Mean :  0.13   certainty_FPFH :  0.02
#  y_train_true 0.0
# threshold_y_true :  0.42 Mean :  0.28   certainty_FPFH :  0.0
#  y_train_true 0.0
# threshold_y_true :  0.41 Mean :  0.58   certainty_FPFH :  0.01
#  y_train_true 0.0
# svp_moved[k] : 337
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.42 Mean :  0.06   certainty_FPFH :  0.0
#  y_train_true 0.0
# threshold_y_true :  0.42 Mean :  0.06   certainty_FPFH :  0.34
# threshold_y_true :  0.41 Mean :  0.58   certainty_FPFH :  0.85
#  y_train_true 1.0
# threshold_y_true :  0.41 Mean :  0.58   certainty_FPFH :  0.0
#  y_train_true 0.0
# threshold_y_true :  0.4 Mean :  0.59   certainty_FPFH :  0.71
#  y_train_true 0.0
# threshold_y_true :  0.4 Mean :  0.6   certainty_FPFH :  0.6
#  y_train_true 0.0
# threshold_y_true :  0.39 Mean :  0.6   certainty_FPFH :  0.04
#  y_train_true 0.0
# prediction removed : 0.8533333333333334
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 0.8279569892473119
# is diferent : 1
# batch Numero  2
#  y_train_true 0.0
#  y_train_true 0.0
#  y_train_true 0.0
#  y_train_true 0.0
#  y_train_true 0.0
#  y_train_true 0.0
# svp_moved[k] : 483
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 452
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 292
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 344
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 293
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 345
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 339
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 485
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 340
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 341
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 342
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 346
# int(old_y_train_true[svp_moved[k]]) : 0
#  y_train_true 1.0
# svp_moved[k] : 579
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 493
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 483
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 6
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 25
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 292
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 575
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 326
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 455
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 339
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 340
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 341
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 346
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.66 Mean :  0.41   certainty_FPFH :  0.57
#  y_train_true 0.0
# threshold_y_true :  0.63 Mean :  0.24   certainty_FPFH :  0.56
#  y_train_true 1.0
# threshold_y_true :  0.6 Mean :  0.21   certainty_FPFH :  0.21
#  y_train_true 0.0
# threshold_y_true :  0.6 Mean :  0.3   certainty_FPFH :  0.45
# threshold_y_true :  0.57 Mean :  0.28   certainty_FPFH :  0.2
#  y_train_true 0.0
# svp_moved[k] : 620
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 410
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 406
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 405
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 494
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 317
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.57 Mean :  0.28   certainty_FPFH :  0.5
#  y_train_true 0.0
# threshold_y_true :  0.54 Mean :  0.26   certainty_FPFH :  0.52
#  y_train_true 0.0
# svp_moved[k] : 692
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 691
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 494
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 410
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 703
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 291
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.54 Mean :  0.1   certainty_FPFH :  0.28
#  y_train_true 0.0
# threshold_y_true :  0.52 Mean :  0.18   certainty_FPFH :  0.22
#  y_train_true 1.0
# threshold_y_true :  0.52 Mean :  0.21   certainty_FPFH :  0.37
# threshold_y_true :  0.5 Mean :  0.18   certainty_FPFH :  0.35
#  y_train_true 0.0
# threshold_y_true :  0.48 Mean :  0.11   certainty_FPFH :  0.11
#  y_train_true 0.0
# threshold_y_true :  0.46 Mean :  0.34   certainty_FPFH :  0.22
#  y_train_true 0.0
# threshold_y_true :  0.44 Mean :  0.33   certainty_FPFH :  0.4
#  y_train_true 0.0
# threshold_y_true :  0.42 Mean :  0.31   certainty_FPFH :  0.58
#  y_train_true 0.0
# threshold_y_true :  0.42 Mean :  0.34   certainty_FPFH :  0.38
# svp_moved[k] : 355
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 353
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 352
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.42 Mean :  0.24   certainty_FPFH :  0.45
#  y_train_true 0.0
# threshold_y_true :  0.41 Mean :  0.58   certainty_FPFH :  0.85
#  y_train_true 0.0
# svp_moved[k] : 364
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 359
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 189
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 188
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 187
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.5 Mean :  0.11   certainty_FPFH :  0.23
#  y_train_true 0.0
# svp_moved[k] : 635
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 364
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 187
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.5 Mean :  0.09   certainty_FPFH :  0.02
#  y_train_true 0.0
# threshold_y_true :  0.48 Mean :  0.13   certainty_FPFH :  0.24
#  y_train_true 0.0
# threshold_y_true :  0.48 Mean :  0.34   certainty_FPFH :  0.28
# threshold_y_true :  0.47 Mean :  0.23   certainty_FPFH :  0.12
#  y_train_true 0.0
# threshold_y_true :  0.45 Mean :  0.29   certainty_FPFH :  0.1
#  y_train_true 0.0
# threshold_y_true :  0.44 Mean :  0.19   certainty_FPFH :  0.55
#  y_train_true 0.0
# svp_moved[k] : 567
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 181
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 172
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 177
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.44 Mean :  0.13   certainty_FPFH :  0.49
#  y_train_true 0.0
# svp_moved[k] : 171
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.44 Mean :  0.28   certainty_FPFH :  0.29
#  y_train_true 0.0
# threshold_y_true :  0.44 Mean :  0.27   certainty_FPFH :  0.18
# threshold_y_true :  0.43 Mean :  0.26   certainty_FPFH :  0.03
#  y_train_true 0.0
# threshold_y_true :  0.42 Mean :  0.32   certainty_FPFH :  0.69
#  y_train_true 0.0
# threshold_y_true :  0.41 Mean :  0.58   certainty_FPFH :  0.42
#  y_train_true 0.0
# threshold_y_true :  0.4 Mean :  0.59   certainty_FPFH :  0.14
#  y_train_true 0.0
# threshold_y_true :  0.39 Mean :  0.6   certainty_FPFH :  0.34
#  y_train_true 0.0
# threshold_y_true :  0.39 Mean :  0.6   certainty_FPFH :  0.13
# threshold_y_true :  0.38 Mean :  0.61   certainty_FPFH :  0.51
#  y_train_true 0.0
# threshold_y_true :  0.37 Mean :  0.62   certainty_FPFH :  0.71
#  y_train_true 0.0
# threshold_y_true :  0.36 Mean :  0.63   certainty_FPFH :  0.28
#  y_train_true 0.0
# svp_moved[k] : 175
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 172
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 167
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 166
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 165
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.43 Mean :  0.21   certainty_FPFH :  0.2
#  y_train_true 0.0
# threshold_y_true :  0.42 Mean :  0.08   certainty_FPFH :  0.07
#  y_train_true 0.0
# threshold_y_true :  0.42 Mean :  0.25   certainty_FPFH :  0.39
# threshold_y_true :  0.41 Mean :  0.58   certainty_FPFH :  0.51
#  y_train_true 0.0
# threshold_y_true :  0.4 Mean :  0.59   certainty_FPFH :  0.29
#  y_train_true 1.0
# threshold_y_true :  0.4 Mean :  0.6   certainty_FPFH :  0.28
#  y_train_true 1.0
# svp_moved[k] : 345
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 328
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 327
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 326
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.44 Mean :  0.23   certainty_FPFH :  0.64
#  y_train_true 0.0
# svp_moved[k] : 345
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 342
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 120
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 352
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 121
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 129
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 127
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 175
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.44 Mean :  0.12   certainty_FPFH :  0.08
#  y_train_true 0.0
# threshold_y_true :  0.44 Mean :  0.33   certainty_FPFH :  0.18
# threshold_y_true :  0.43 Mean :  0.2   certainty_FPFH :  0.13
#  y_train_true 0.0
# threshold_y_true :  0.42 Mean :  0.34   certainty_FPFH :  0.15
#  y_train_true 0.0
# threshold_y_true :  0.41 Mean :  0.58   certainty_FPFH :  0.09
#  y_train_true 0.0
# threshold_y_true :  0.41 Mean :  0.58   certainty_FPFH :  0.7
#  y_train_true 0.0
# threshold_y_true :  0.4 Mean :  0.59   certainty_FPFH :  0.17
#  y_train_true 0.0
# threshold_y_true :  0.4 Mean :  0.59   certainty_FPFH :  0.72
# svp_moved[k] : 510
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 459
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 419
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 340
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 498
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 353
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 347
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 349
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 351
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 497
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 352
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 499
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 354
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 356
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 350
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 408
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 502
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 357
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 359
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.54 Mean :  0.35   certainty_FPFH :  0.14
#  y_train_true 0.0
# svp_moved[k] : 538
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 352
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 497
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 351
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 526
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 350
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 496
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 437
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 349
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 405
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 345
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 356
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 499
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 353
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 498
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 347
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 462
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 419
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 598
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 481
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 482
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 502
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.54 Mean :  0.11   certainty_FPFH :  0.17
#  y_train_true 0.0
# threshold_y_true :  0.53 Mean :  0.27   certainty_FPFH :  0.79
#  y_train_true 0.0
# svp_moved[k] : 502
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 499
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 498
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 496
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 598
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 425
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 421
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 344
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 345
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 358
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 371
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 359
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 347
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 349
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 497
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 352
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 346
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 369
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 348
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 406
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.53 Mean :  0.23   certainty_FPFH :  0.33
#  y_train_true 1.0
# svp_moved[k] : 346
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 348
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 349
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 355
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 498
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 421
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 294
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.53 Mean :  0.31   certainty_FPFH :  0.14
#  y_train_true 0.0
# threshold_y_true :  0.53 Mean :  0.09   certainty_FPFH :  0.1
# threshold_y_true :  0.52 Mean :  0.31   certainty_FPFH :  0.48
#  y_train_true 0.0
# threshold_y_true :  0.52 Mean :  0.2   certainty_FPFH :  0.5
#  y_train_true 0.0
# svp_moved[k] : 584
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 330
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.52 Mean :  0.21   certainty_FPFH :  0.12
#  y_train_true 0.0
# threshold_y_true :  0.51 Mean :  0.16   certainty_FPFH :  0.1
#  y_train_true 0.0
# threshold_y_true :  0.51 Mean :  0.26   certainty_FPFH :  0.82
#  y_train_true 0.0
# threshold_y_true :  0.51 Mean :  0.25   certainty_FPFH :  0.14
# threshold_y_true :  0.5 Mean :  0.22   certainty_FPFH :  0.18
#  y_train_true 0.0
# threshold_y_true :  0.5 Mean :  0.34   certainty_FPFH :  0.14
#  y_train_true 0.0
# threshold_y_true :  0.49 Mean :  0.19   certainty_FPFH :  0.4
#  y_train_true 0.0
# threshold_y_true :  0.48 Mean :  0.29   certainty_FPFH :  0.07
#  y_train_true 0.0
# threshold_y_true :  0.48 Mean :  0.17   certainty_FPFH :  0.62
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 0.010309278350515464
# is diferent : 1
# prediction removed : 0.0
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 0.945054945054945
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 0.7634408602150538
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 0.01652892561983471
# is diferent : 1
# prediction removed : 0.0
# is diferent : 1
# prediction removed : 0.0
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
#  y_train_true 0.0
# threshold_y_true :  0.52 Mean :  0.08   certainty_FPFH :  0.96
# svp_moved[k] : 358
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 357
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.52 Mean :  0.27   certainty_FPFH :  0.81
#  y_train_true 1.0
# threshold_y_true :  0.51 Mean :  0.25   certainty_FPFH :  0.4
#  y_train_true 0.0
# svp_moved[k] : 637
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.51 Mean :  0.24   certainty_FPFH :  0.06
#  y_train_true 0.0
# svp_moved[k] : 352
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 351
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 347
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.51 Mean :  0.29   certainty_FPFH :  0.01
#  y_train_true 0.0
# svp_moved[k] : 694
# int(old_y_train_true[svp_moved[k]]) : 0
# svp_moved[k] : 352
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.51 Mean :  0.2   certainty_FPFH :  0.01
#  y_train_true 0.0
# threshold_y_true :  0.51 Mean :  0.33   certainty_FPFH :  0.03
# threshold_y_true :  0.51 Mean :  0.34   certainty_FPFH :  0.01
#  y_train_true 0.0
# threshold_y_true :  0.5 Mean :  0.09   certainty_FPFH :  0.05
#  y_train_true 0.0
# threshold_y_true :  0.5 Mean :  0.27   certainty_FPFH :  0.01
#  y_train_true 0.0
# threshold_y_true :  0.49 Mean :  0.29   certainty_FPFH :  0.85
#  y_train_true 0.0
# threshold_y_true :  0.48 Mean :  0.34   certainty_FPFH :  0.02
#  y_train_true 0.0
# prediction removed : 0.0
# is diferent : 1
# prediction removed : 0.2018348623853211
# is diferent : 1
# prediction removed : 0.9696969696969697
# is diferent : 1
# prediction removed : 0.01020408163265306
# is diferent : 1
# prediction removed : 0.26582278481012656
# is diferent : 1
# prediction removed : 1.0
# is diferent : 1
# prediction removed : 0.8545454545454545
# is diferent : 1
# batch Numero  3
# svp_moved[k] : 335
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 334
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 333
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 331
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 330
# int(old_y_train_true[svp_moved[k]]) : 1
#  y_train_true 0.0
#  y_train_true 0.0
#  y_train_true 0.0
#  y_train_true 0.0
# threshold_y_true :  0.55 Mean :  0.18   certainty_FPFH :  0.04
#  y_train_true 0.0
# threshold_y_true :  0.55 Mean :  0.29   certainty_FPFH :  0.0
# svp_moved[k] : 341
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 340
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 337
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 282
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.55 Mean :  0.1   certainty_FPFH :  0.76
#  y_train_true 0.0
# svp_moved[k] : 179
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 173
# int(old_y_train_true[svp_moved[k]]) : 0
# threshold_y_true :  0.55 Mean :  0.13   certainty_FPFH :  0.38
#  y_train_true 1.0
# svp_moved[k] : 745
# int(old_y_train_true[svp_moved[k]]) : 1
# svp_moved[k] : 179
# int(old_y_train_true[svp_moved[k]]) : 1
# threshold_y_true :  0.55 Mean :  0.2   certainty_FPFH :  0.08
#  y_train_true 0.0
# threshold_y_true :  0.5 Mean :  0.13   certainty_FPFH :  0.83
#  y_train_true 0.0
# threshold_y_true :  0.45 Mean :  0.32   certainty_FPFH :  0.17
#  y_train_true 0.0
# threshold_y_true :  0.45 Mean :  0.13   certainty_FPFH :  0.13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/.local/lib/python3.8/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
print(sum(y2))
print(len(y2))

print("ratio :",sum(y2)/len(y2))
# Out:
# 24
# 46
# ratio : 0.5217391304347826

# %%
for i in range(len(batch_y_train_acc_exp)):
    print("Batch Numero :",i)
    #print("nb de données avant oublie :",len(noForget_batch_y_train_acc_exp[i]))
    #print("Taux d'erreur avant oublie :",myfct.error_pred(noForget_batch_y_train_acc_exp[i][:],noForget_batch_y_train_acc_true[i][:]))
    print("nb de données apres oublie :",len(batch_y_train_acc_exp[i]))
    print("Taux d'erreur apres oublie :",myfct.error_pred(batch_y_train_acc_exp[i][:],batch_y_train_acc_true[i][:]))
# Out:
# Batch Numero : 0
# nb de données apres oublie : 72
# Taux d'erreur apres oublie : [0.05263158 0.22641509 0.18055556]
# Batch Numero : 1
# nb de données apres oublie : 75
# Taux d'erreur apres oublie : [0.         0.31578947 0.24      ]

# %%
FPFHL_folder = "env3_table3"
nb_scenes = 13

###DISPLAY Precision, Recall & Accuracy of the robotic arm
#title = "Interpretation des résultats de la simulation"
#mydisplay.displayNormalizedResults(title,batch_y_train_acc_exp,batch_y_train_acc_true,batch_X_train_acc_rough)

###DISPLAY Precision, Recall & Accuracy from a database without forgetting
#title = "Phase d'exploitation à partir des données rééquilibrées de 20 scènes sans oublie d'outlier"

#from sklearn.neighbors import KNeighborsClassifier
#model = KNeighborsClassifier(n_neighbors=10)
#model = SVC(kernel = 'rbf',probability=True,class_weight = 'balanced')
#mydisplay.displayNormalizedResults2(model,FPFHL_folder,nb_scenes,title,noForget_batch_y_train_acc_exp,noForget_batch_y_train_acc_true,noForget_batch_X_train_acc_rough)


###DISPLAY Precision, Recall & Accuracy from a database
#title = "Phase d'exploitation à partir des données rééquilibrées de 20 scènes avec oublie"
title = "Phase d'exploitation"

#from sklearn.neighbors import KNeighborsClassifier
#model = KNeighborsClassifier(n_neighbors=10)
#model = SVC(kernel = 'rbf',probability=True,class_weight = 'balanced')
model = RandomForestClassifier()
mydisplay.displayNormalizedResults2(model,FPFHL_folder,nb_scenes,title,batch_y_train_acc_exp,batch_y_train_acc_true,batch_X_train_acc_rough)


###DISPLAY Precision, Recall & Accuracy from truth
#title = "Phase d'exploitation à partir des données rééquilibrées de 20 scènes avec oublie et veritable label"

#from sklearn.neighbors import KNeighborsClassifier
#model = KNeighborsClassifier(n_neighbors=10)
#model = SVC(kernel = 'rbf',probability=True,class_weight = 'balanced')
#model = RandomForestClassifier()
#mydisplay.displayNormalizedResults2(model,FPFHL_folder,nb_scenes,title,batch_y_train_acc_true,batch_y_train_acc_true,batch_X_train_acc_rough)



###DISPLAY Error Rate
title = "Error Rates au cours de l'apprentissage testé sur une base de données rééquilibrées de 20 scènes\n"
y_lim = (0,0.3)
num_batch = 0
mydisplay.error_rates_on_Dataset(num_batch,model,y_lim,FPFHL_folder,nb_scenes,title,batch_y_train_acc_exp,batch_y_train_acc_true,batch_X_train_acc_rough)

# %% [markdown]
# ## Test de segmentation d'une scene

# %%
nomDossier = "env1_table1"
numIter = "3"
numeroDeScene = "6"
paths_to_output = "../outputs/"

# %%
from sklearn.preprocessing import StandardScaler 

#On entraine un modèle grace aux données recuperé lors du batch "numBatch"
numBatch = 0
batch_y_train_acc_true[numBatch][0] = 1
model.fit(myfct.normalize(batch_X_train_acc_rough[numBatch][:]),batch_y_train_acc_exp[numBatch][:])
#model.fit(myfct.normalize(new_X),new_y)

sceneTest=pd.read_csv("../outputs/"+nomDossier+"/fpfh/fpfh_scene"+str(numeroDeScene)+"iter"+str(numIter)+".txt")
sceneTest.head()



#NORMALISER LES DONN2ES TESTS!!!!
scaler=StandardScaler() 
scaler.fit(sceneTest.drop('label',axis=1))
scaled_features = scaler.transform(sceneTest.drop('label',axis=1))
sceneTest_feat = pd.DataFrame(scaled_features,columns=sceneTest.columns[:-1])
sceneTest_feat.head()


from sklearn.metrics import classification_report,confusion_matrix

testPrediction = model.predict(myfct.normalize(scaled_features)) #Ici on choisit le model que l'on veut tester
testProba = model.predict_proba(myfct.normalize(scaled_features))
#print(confusion_matrix(y_test,pred))
testReality = np.array(sceneTest["label"])
testReality = np.concatenate(([0],testReality))

# %% [markdown]
# ### Display SuperVoxels Persistant

# %%
#segmented = mydisplay.read_xyzrgbls(paths_to_output+str(nomDossier)+"/vccs/vccs_scene"+str(numeroDeScene)+"iter"+numIter+".xyzrgbls")
segmented = mydisplay.read_xyzrgbls(paths_to_output+str(nomDossier)+"/nuageDisplay/nuage_scene"+str(numeroDeScene)+"iter"+numIter+".xyzrgbls")
svp_centroides = mydisplay.read_xyzrgbls(paths_to_output+str(nomDossier)+"/centroides/centroides_scene"+str(numeroDeScene)+"iter"+numIter+".xyzrgbls")
sceneTest=pd.read_csv("../outputs/"+nomDossier+"/fpfh/fpfh_scene"+str(numeroDeScene)+"iter"+str(numIter)+".txt")
X1,Y1,Z1,X2,Y2,Z2 = [],[],[],[],[],[]
for i in range(len(segmented)):
    X1.append(segmented[i][0])
    Y1.append(segmented[i][1])
    Z1.append(0)#segmented[i][2])
    
for i in range(len(svp_centroides)):
    if(sceneTest["label"][i] == 1):
        X2.append(svp_centroides[i][0])
        Y2.append(svp_centroides[i][1])
        Z2.append(0)#svp_centroides[i][2]+1000)
    
svp_obj = []
for i in range(len(testPrediction)):
    if(testPrediction[i]):
        svp_obj.append(i+1) 
        
colors = []
for i in range (len(segmented)):
    colors.append((segmented[i][3]/255, segmented[i][4]/255, segmented[i][5]/255))
    #for j in range(len(svp_obj)):
        #if(segmented[i][7] == svp_obj[j]):
        #    colors[-1] = (1.0, 1.0, 0.0)


colors = np.array(colors)

categories = []
for i in range(len(segmented)):
    categories.append(i)
    
fig = plt.figure(figsize = (18,15))
ax = fig.gca(projection='3d')
ax.view_init(90, 270)
ax.scatter(X1, Y1, Z1, c=colors[categories], marker='.')
#ax.scatter(X2, Y2, Z2, c='yellow',linewidths = 4, marker='.')

# %%
#segmented = mydisplay.read_xyzrgbls(paths_to_output+str(nomDossier)+"/vccs/vccs_scene"+str(numeroDeScene)+"iter"+numIter+".xyzrgbls")
segmented = mydisplay.read_xyzrgbls(paths_to_output+str(nomDossier)+"/nuageDisplay/nuage_scene"+str(numeroDeScene)+"iter"+numIter+".xyzrgbls")
svp_centroides = mydisplay.read_xyzrgbls(paths_to_output+str(nomDossier)+"/centroides/centroides_scene"+str(numeroDeScene)+"iter"+numIter+".xyzrgbls")
X1,Y1,Z1,X2,Y2,Z2 = [],[],[],[],[],[]

for i in range(len(segmented)):
    X1.append(segmented[i][0])
    Y1.append(segmented[i][1])
    Z1.append(0)#segmented[i][2])
    
for i in range(len(testPrediction)):
    if(testPrediction[i]):
        X2.append(svp_centroides[i][0])
        Y2.append(svp_centroides[i][1])
        Z2.append(0)#svp_centroides[i][2]+1000)
    

        
colors = []
for i in range (len(segmented)):
    colors.append((segmented[i][3]/255, segmented[i][4]/255, segmented[i][5]/255))
    #for j in range(len(svp_obj)):
        #if(segmented[i][7] == svp_obj[j]):
        #    colors[-1] = (1.0, 1.0, 0.0)


colors = np.array(colors)

categories = []
for i in range(len(segmented)):
    categories.append(i)
    
fig = plt.figure(figsize = (18,15))
ax = fig.gca(projection='3d')
ax.view_init(90, 270)
ax.scatter(X1, Y1, Z1, c=colors[categories], marker='.')
ax.scatter(X2, Y2, Z2, c='yellow',linewidths = 4, marker='.')

# %%
#segmented = mydisplay.read_xyzrgbls(paths_to_output+str(nomDossier)+"/vccs/vccs_scene"+str(numeroDeScene)+"iter"+numIter+".xyzrgbls")
segmented = mydisplay.read_xyzrgbls(paths_to_output+str(nomDossier)+"/nuageDisplay/nuage_scene"+str(numeroDeScene)+"iter"+numIter+".xyzrgbls")
svp_centroides = mydisplay.read_xyzrgbls(paths_to_output+str(nomDossier)+"/centroides/centroides_scene"+str(numeroDeScene)+"iter"+numIter+".xyzrgbls")
X1,Y1,Z1,X2,Y2,Z2 = [],[],[],[],[],[]

for i in range(len(segmented)):
    X1.append(segmented[i][0])
    Y1.append(segmented[i][1])
    Z1.append(0)#segmented[i][2])
    
for i in range(len(testProba)):
    if(testProba[i][1]>0.97):
        X2.append(svp_centroides[i][0])
        Y2.append(svp_centroides[i][1])
        Z2.append(0)#svp_centroides[i][2]+1000)
        
    

        
colors = []
for i in range (len(segmented)):
    colors.append((segmented[i][3]/255, segmented[i][4]/255, segmented[i][5]/255))
    #for j in range(len(svp_obj)):
        #if(segmented[i][7] == svp_obj[j]):
        #    colors[-1] = (1.0, 1.0, 0.0)


colors = np.array(colors)

categories = []
for i in range(len(segmented)):
    categories.append(i)
    
fig = plt.figure(figsize = (18,15))
ax = fig.gca(projection='3d')
ax.view_init(90, 270)
ax.scatter(X1, Y1, Z1, c=colors[categories], marker='.')
ax.scatter(X2, Y2, Z2, c='blue',linewidths = 4, marker='.')

# %%
segmented = mydisplay.read_xyzrgbls(paths_to_output+str(nomDossier)+"/vccs/vccs_scene"+str(numeroDeScene)+"iter"+numIter+".xyzrgbls")

X,Y,Z = [],[],[]
for i in range(len(segmented)):
    X.append(segmented[i][0])
    Y.append(segmented[i][1])
    Z.append(segmented[i][2])
    
svp_obj = []
for i in range(len(testPrediction)):
    if(testPrediction[i]):
        svp_obj.append(i+1) 
        
colors = []
for i in range (len(segmented)):
    colors.append((segmented[i][3]/255, segmented[i][4]/255, segmented[i][5]/255))
    #for j in range(len(svp_obj)):
        #if(segmented[i][7] == svp_obj[j]):
        #    colors[-1] = (1.0, 1.0, 0.0)


colors = np.array(colors)

categories = []
for i in range(len(segmented)):
    categories.append(i)
    
fig = plt.figure(figsize = (18,15))
ax = fig.gca(projection='3d')
ax.view_init(90-35, 270)
ax.scatter(X, Y, Z, c=colors[categories], marker='.')
#ax.scatter(400, 400, 1000, c='yellow',linewidths = 5, marker='o')

# %%
segmented = mydisplay.read_xyzrgbls(paths_to_output+str(nomDossier)+"/vccs/vccs_scene"+str(numeroDeScene)+"iter"+numIter+".xyzrgbls")

X,Y,Z = [],[],[]
for i in range(len(segmented)):
    X.append(segmented[i][0])
    Y.append(segmented[i][1])
    Z.append(segmented[i][2])
    
svp_obj = []
for i in range(len(testProba)):
    if(testProba[i][1]>0.93):
        svp_obj.append(i+1) 
        
colors = []
for i in range (len(segmented)):
    colors.append((segmented[i][3]/255, segmented[i][4]/255, segmented[i][5]/255))
    for j in range(len(svp_obj)):
        if(segmented[i][7] == svp_obj[j]):
            colors[-1] = (1.0, 1.0, 0.0)


colors = np.array(colors)

categories = []
for i in range(len(segmented)):
    categories.append(i)
    
fig = plt.figure(figsize = (18,15))
ax = fig.gca(projection='3d',proj_type = 'persp')

ax.view_init(90-35, -90)
#ax.zaxis_inverted
ax.scatter(X, Y, Z, c=colors[categories], marker='.')

# %%
segmented = mydisplay.read_xyzrgbls(paths_to_output+str(nomDossier)+"/vccs/vccs_scene"+str(numeroDeScene)+"iter"+numIter+".xyzrgbls")

X,Y,Z = [],[],[]
for i in range(len(segmented)):
    X.append(segmented[i][0])
    Y.append(segmented[i][1]+((-2.82/4.5)+1)*128)
    Z.append(segmented[i][2]+((+3.42/4.5)+1)*128)
    
colors = []
for i in range (3000):
    colors.append((random.uniform(0,1), random.uniform(0,1), random.uniform(0,1), 1.0))
colors = np.array(colors)

categories = []
for i in range(len(segmented)):
    categories.append(int(segmented[i][-1]))
    
fig = plt.figure(figsize = (18,15))
ax = fig.gca(projection='3d')
ax.view_init(90-35, -90)
ax.scatter(X, Y, Z, c=colors[categories], marker='.')

# %%
sceneTest=pd.read_csv("../outputs/"+nomDossier+"/fpfh/fpfh_scene"+str(numeroDeScene)+"iter"+str(numIter)+".txt")

scaler=StandardScaler() 
scaler.fit(sceneTest.drop('label',axis=1))
scaled_features = scaler.transform(sceneTest.drop('label',axis=1))
sceneTest_feat = pd.DataFrame(scaled_features,columns=sceneTest.columns[:-1])


sv_obj = []
for i in range(len(sceneTest)):
    if(sceneTest["label"][i] == 1):
        sv_obj.append(i+1)
#sv_moved = [846,242,838,247,502,299,567,248,500,246,536,600]#true_numbers#[]
#for i in range(len(y_train_true)):
#    if(y_train_true[i] == 1):
#        sv_moved.append(i+1)

segmented = mydisplay.read_xyzrgbls(paths_to_output+str(nomDossier)+"/vccs/vccs_scene"+str(numeroDeScene)+"iter"+numIter+".xyzrgbls")

X,Y,Z = [],[],[]
for i in range(len(segmented)):
    X.append(segmented[i][0])
    Y.append(segmented[i][1])
    Z.append(segmented[i][2])
    
colors = []
for i in range (len(segmented)):
    colors.append((segmented[i][3]/256, segmented[i][4]/256, segmented[i][5]/256))
    for j in range(len(sv_obj)):
        if(segmented[i][7] == sv_obj[j]):
            colors[-1] = (1, 1, 0)


colors = np.array(colors)

categories = []
for i in range(len(segmented)):
    categories.append(i)
    
fig = plt.figure(figsize = (18,15))

ax = fig.gca(projection='3d')

ax.view_init(90-35, 270)
ax.scatter(X, Y, Z, c=colors[categories], marker='.')

# %%
6.3707/0.01327
# Out:
# 480.0828937452901
